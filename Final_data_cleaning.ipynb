# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Akhand Pratap Singh/Desktop/DataAnalyst.csv")
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
# Unnamed: 0           2253 non-null int64
# Job Title            2253 non-null object
# Salary Estimate      2253 non-null object
# Job Description      2253 non-null object
# Rating               2253 non-null float64
# Company Name         2252 non-null object
# Location             2253 non-null object
# Headquarters         2253 non-null object
# Size                 2253 non-null object
# Founded              2253 non-null int64
# Type of ownership    2253 non-null object
# Industry             2253 non-null object
# Sector               2253 non-null object
# Revenue              2253 non-null object
# Competitors          2253 non-null object
# Easy Apply           2253 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.7+ KB

# %%
df.shape
# Out:
# (2253, 16)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df['Job Title'].value_counts()
# Out:
# Data Analyst                                                                        405
# Senior Data Analyst                                                                  90
# Junior Data Analyst                                                                  30
# Business Data Analyst                                                                28
# Sr. Data Analyst                                                                     21
# Data Analyst II                                                                      17
# Data Analyst Junior                                                                  17
# Data Quality Analyst                                                                 17
# Data Governance Analyst                                                              16
# Lead Data Analyst                                                                    15
# Data Reporting Analyst                                                               13
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2252, 15)

# %%
#****
df['Salary Estimate'].head()
# Out:
# 0    $37K-$66K (Glassdoor est.)
# 1    $37K-$66K (Glassdoor est.)
# 2    $37K-$66K (Glassdoor est.)
# 3    $37K-$66K (Glassdoor est.)
# 4    $37K-$66K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
df['Salary Estimate'].str.split('-').head()
# Out:
# 0    [$37K, $66K (Glassdoor est.)]
# 1    [$37K, $66K (Glassdoor est.)]
# 2    [$37K, $66K (Glassdoor est.)]
# 3    [$37K, $66K (Glassdoor est.)]
# 4    [$37K, $66K (Glassdoor est.)]
# Name: Salary Estimate, dtype: object

# %%
new=df["Salary Estimate"].str.split(" ", n = 1, expand = True)
new.head()
# Out:
#            0                 1
# 0  $37K-$66K  (Glassdoor est.)
# 1  $37K-$66K  (Glassdoor est.)
# 2  $37K-$66K  (Glassdoor est.)
# 3  $37K-$66K  (Glassdoor est.)
# 4  $37K-$66K  (Glassdoor est.)

# %%
sal_range=new[0].str.split('-',n=1,expand=True)
sal_range.head()
# Out:
#       0     1
# 0  $37K  $66K
# 1  $37K  $66K
# 2  $37K  $66K
# 3  $37K  $66K
# 4  $37K  $66K

# %%
df['Lower'] = sal_range[0]
df['Upper'] = sal_range[1]
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df.drop('Salary Estimate',axis=1,inplace=True)
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df.replace(-1,np.nan,inplace=True)

# %%
df.replace(-1.0,np.nan,inplace=True)
df.replace('-1',np.nan,inplace=True)

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df.isnull().sum()
# Out:
# Job Title               0
# Job Description         0
# Rating                271
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1731
# Easy Apply           2172
# Lower                   0
# Upper                   0
# dtype: int64

# %%
na_features = [features for features in df.columns if df[features].isnull().sum()>=1]
na_features
# Out:
# ['Rating',
#  'Headquarters',
#  'Size',
#  'Founded',
#  'Type of ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Competitors',
#  'Easy Apply']

# %%
for feature in na_features:
    print(feature, np.round(df[feature].isnull().mean(),4),'% Missing Values.')
# Out:
# Rating 0.1203 % Missing Values.
# Headquarters 0.0759 % Missing Values.
# Size 0.0719 % Missing Values.
# Founded 0.2926 % Missing Values.
# Type of ownership 0.0719 % Missing Values.
# Industry 0.1563 % Missing Values.
# Sector 0.1563 % Missing Values.
# Revenue 0.0719 % Missing Values.
# Competitors 0.7687 % Missing Values.
# Easy Apply 0.9645 % Missing Values.

# %%
df['Lower']=df['Lower'].str.replace('K','000')
df['Lower']=df['Lower'].str.replace('$','')
df['Upper']=df['Upper'].str.replace('K','000')
df['Upper']=df['Upper'].str.replace('$','')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df['Upper'].unique()
# Out:
# array([ 66000,  87000,  88000,  85000,  76000, 110000,  78000, 127000,
#         90000,  52000,  74000, 132000, 114000,  96000,  47000,  59000,
#         81000,  69000, 112000,  54000, 103000,  70000,  45000,  63000,
#         82000,  92000, 129000,  38000, 123000,  94000, 102000,  68000,
#         44000, 113000,  93000,  89000, 122000, 124000,  61000,  48000,
#         53000,  86000, 190000, 151000, 116000, 104000,  42000,  77000,
#         72000,  67000,  75000,  99000, 178000, 159000, 120000, 101000,
#             1,  56000,  91000, 100000], dtype=int64)

# %%
df['Lower'].unique()
# Out:
# array([ 37000,  46000,  51000,  59000,  43000,  60000,  41000,  45000,
#         73000,  84000,  27000,  42000,  77000,  98000,  48000,  26000,
#         31000,  47000,  49000,  30000,  55000,  57000,  35000,  65000,
#        113000,  67000,  97000,  68000,  29000,  74000,  53000,  38000,
#         64000,  50000,  76000,  34000,  24000,  44000, 110000,  89000,
#         69000,  58000,  63000,  40000,  28000,  54000,  99000,  93000,
#         82000,      0,  32000,  36000,  78000], dtype=int64)

# %%
df['Lower'].replace('',0,inplace=True)
df['Lower']=df['Lower'].astype('int')

# %%
df['Upper'].replace('',0,inplace=True)
df['Upper']=df['Upper'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2252 entries, 0 to 2252
# Data columns (total 16 columns):
# Job Title            2252 non-null object
# Job Description      2252 non-null object
# Rating               1981 non-null float64
# Company Name         2252 non-null object
# Location             2252 non-null object
# Headquarters         2081 non-null object
# Size                 2090 non-null object
# Founded              1593 non-null float64
# Type of ownership    2090 non-null object
# Industry             1900 non-null object
# Sector               1900 non-null object
# Revenue              2090 non-null object
# Competitors          521 non-null object
# Easy Apply           80 non-null object
# Lower                2252 non-null int32
# Upper                2252 non-null int32
# dtypes: float64(2), int32(2), object(12)
# memory usage: 281.5+ KB

# %%
df['Average_Sal'] = (df['Lower']+df['Upper'])/2

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
st = df['Location'].str.split(',',n=1,expand=True)
df['State'] = st[1]
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df['Size'].head()
# Out:
# 0      201 to 500 employees
# 1          10000+ employees
# 2    1001 to 5000 employees
# 3      201 to 500 employees
# 4     501 to 1000 employees
# Name: Size, dtype: object

# %%
df['Size'].str.split(' ').head()
# Out:
# 0      [201, to, 500, employees]
# 1            [10000+, employees]
# 2    [1001, to, 5000, employees]
# 3      [201, to, 500, employees]
# 4     [501, to, 1000, employees]
# Name: Size, dtype: object

# %%
new=df["Size"].str.split(" ", n =4, expand = True)
new.head()
# Out:
#         0          1     2          3
# 0     201         to   500  employees
# 1  10000+  employees  None       None
# 2    1001         to  5000  employees
# 3     201         to   500  employees
# 4     501         to  1000  employees

# %%
df['Min_Employees'] = new[0]
df['Max_Employees'] = new[2]
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df['Max_Employees'].unique()
# Out:
# array(['500', None, '5000', '1000', '10000', '50', '200', nan],
#       dtype=object)

# %%
df['Min_Employees'].unique()
# Out:
# array(['201', '10000+', '1001', '501', '5001', '1', '51', 'Unknown', nan],
#       dtype=object)

# %%
df.drop('Size',axis=1,inplace=True)
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# ...

# %%
df['Revenue'].head()
# Out:
# 0    $100 to $500 million (USD)
# 1        $2 to $5 billion (USD)
# 2      Unknown / Non-Applicable
# 3     $50 to $100 million (USD)
# 4    $100 to $500 million (USD)
# Name: Revenue, dtype: object

# %%
df['Revenue'].str.split(' ').head()
# Out:
# 0    [$100, to, $500, million, (USD)]
# 1        [$2, to, $5, billion, (USD)]
# 2        [Unknown, /, Non-Applicable]
# 3     [$50, to, $100, million, (USD)]
# 4    [$100, to, $500, million, (USD)]
# Name: Revenue, dtype: object

# %%
new=df["Revenue"].str.split(" ", n =3, expand = True)
new.head()
# Out:
#          0   1               2              3
# 0     $100  to            $500  million (USD)
# 1       $2  to              $5  billion (USD)
# 2  Unknown   /  Non-Applicable           None
# 3      $50  to            $100  million (USD)
# 4     $100  to            $500  million (USD)

# %%
new[3].value_counts()
# Out:
# million (USD)       935
# billion (USD)       272
# $1 billion (USD)     79
# Name: 3, dtype: int64

# %%
new[3].replace('$1 billion (USD)','billion (USD)',inplace=True)
new.head()
# Out:
#          0   1               2              3
# 0     $100  to            $500  million (USD)
# 1       $2  to              $5  billion (USD)
# 2  Unknown   /  Non-Applicable           None
# 3      $50  to            $100  million (USD)
# 4     $100  to            $500  million (USD)

# %%
new[3].value_counts()
# Out:
# million (USD)    935
# billion (USD)    351
# Name: 3, dtype: int64

# %%
new[3].replace('billion (USD)','1000 ',inplace=True)
new.head()
# Out:
#          0   1               2              3
# 0     $100  to            $500  million (USD)
# 1       $2  to              $5          1000
# 2  Unknown   /  Non-Applicable           None
# 3      $50  to            $100  million (USD)
# 4     $100  to            $500  million (USD)

# %%
new[3].replace('million (USD)','1',inplace=True)
new.head()
# Out:
#          0   1               2      3
# 0     $100  to            $500      1
# 1       $2  to              $5  1000
# 2  Unknown   /  Non-Applicable   None
# 3      $50  to            $100      1
# 4     $100  to            $500      1

# %%
#Didn't worked out as it is as a string
#new[0].replace('$',' ',inplace=True)
#new[2].replace('$',' ',inplace=True)

new[0] = new[0].str.replace('$', '')
new[2] = new[2].str.replace('$', '')
new.head()
# Out:
#          0   1               2      3
# 0      100  to             500      1
# 1        2  to               5  1000
# 2  Unknown   /  Non-Applicable   None
# 3       50  to             100      1
# 4      100  to             500      1

# %%
#df['($) millions'] = '$' + (df['Amount'].astype(float)/1000000).round(2).astype(str) + 'MM'
new[0] = new[0].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-11694c291251> in <module>()
#       1 #df['($) millions'] = '$' + (df['Amount'].astype(float)/1000000).round(2).astype(str) + 'MM'
# ----> 2 new[0] = new[0].astype(str).astype(int)
#
# ~\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...
